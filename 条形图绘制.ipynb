# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
GDP=[12406.8,13908.57,9386.87,9143.64]

# %%
# 中文乱码处理
plt.rcParams['font.sans-serif']=['Microsoft YaHei']
plt.rcParams['axes.unicode_minus']=False

# %%
plt.bar(range(4),GDP)
plt.title('四个直辖市GDP大比拼')
plt.ylabel('GDP')
#增加刻度标签
plt.xticks(range(4),['北京市','上海市','天津市','重庆市'])
plt.ylim([5000,15000])
for x,y in enumerate(GDP):
    plt.text(x,y+100,'%s'%round(y,1),ha='center')
plt.show()

# %%
price = [39.5,39.9,45.4,38.9,33.34]
plt.barh(range(5),price)
plt.xlabel('价格')
plt.yticks(range(5),['亚马逊','当当网','中国图书网','京东','天猫'])
plt.title('不同平台书的最低价比较')
plt.xlim([32,47])
for x,y in enumerate(price):
    plt.text(y+0.1,x,'%s'%y,va='center')
plt.show()

# %%
Y2016 = [15600,12700,11300,4270,3620]
Y2017 = [17400,14800,12000,5200,4020]
labels = ['北京','上海','香港','深圳','广州']
bar_width = 0.35

plt.bar(np.arange(5),Y2016,width=bar_width,label='2016',color='steelblue',alpha=0.8)
plt.bar(np.arange(5)+bar_width,Y2017,width=bar_width,label='2017',color='indianred',alpha=0.8)
plt.xlabel('Top5城市')
plt.ylabel('家庭数量')
plt.title('亿万财富家庭数Top5城市分布')
plt.xticks(np.arange(5)+bar_width,labels)

# 为每个条形图添加数值标签
for x2016,y2016 in enumerate(Y2016):
    plt.text(x2016, y2016+100, '%s' %y2016)

for x2017,y2017 in enumerate(Y2017):
    plt.text(x2017+bar_width, y2017+100, '%s' %y2017)
    
plt.legend()
plt.show()
