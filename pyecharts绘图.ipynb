# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker

# %%
def bar_stack():
    bar = Bar(init_opts=opts.InitOpts(theme='light',width='1000px',height='600px'))
    bar.add_xaxis(Faker.choose())
    #stack值一样的系列会堆叠在一起
    bar.add_yaxis('A',Faker.values(),stack='stack1')
    bar.add_yaxis('B',Faker.values(),stack='stack1')
    bar.add_yaxis('C',Faker.values(),stack='stack2')
    return bar
chart = bar_stack()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e9c1168a8c3847af9743dad404217c95" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e9c1168a8c3847af9743dad404217c95 = echarts.init(
#                     document.getElementById('e9c1168a8c3847af9743dad404217c95'), 'light', {renderer: 'canvas'});
#                 var option_e9c1168a8c3847af9743dad404217c95 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 31,
#                 129,
#                 44,
#                 117,
#                 124,
#                 53,
#                 60
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 101,
#                 134,
#                 26,
#                 65,
#                 143,
#                 124,
#                 53
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "C",
#             "legendHoverLink": true,
#             "data": [
#                 36,
#                 108,
#                 62,
#                 120,
#                 36,
#                 41,
#                 113
#             ],
#             "showBackground": false,
#             "stack": "stack2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B",
#                 "C"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true,
#                 "C": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_e9c1168a8c3847af9743dad404217c95.setOption(option_e9c1168a8c3847af9743dad404217c95);
#         });
#     </script>

# %%
def bar_with_axis_off():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('', Faker.values())
    # 碰上类目标签过长的时候，可以选择关闭坐标轴，直接显示在图形中
    bar.set_series_opts(label_opts=opts.LabelOpts(position='insideLeft', formatter='{b}:{c}'))
    bar.set_global_opts(xaxis_opts=opts.AxisOpts(is_show=False),
                        yaxis_opts=opts.AxisOpts(is_show=False))
    bar.reversal_axis() ##核心代码，用来倒转用的！！！
    return bar


chart = bar_with_axis_off()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2365cc38a2ac441b91e658bb4df62d2e" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2365cc38a2ac441b91e658bb4df62d2e = echarts.init(
#                     document.getElementById('2365cc38a2ac441b91e658bb4df62d2e'), 'light', {renderer: 'canvas'});
#                 var option_2365cc38a2ac441b91e658bb4df62d2e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 128,
#                 66,
#                 34,
#                 113,
#                 47,
#                 53,
#                 70
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "insideLeft",
#                 "margin": 8,
#                 "formatter": "{b}:{c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2365cc38a2ac441b91e658bb4df62d2e.setOption(option_2365cc38a2ac441b91e658bb4df62d2e);
#         });
#     </script>

# %%
import random
x_data = list(range(2010, 2020))
y_data = [random.randint(20, 200) for _ in range(len(x_data))]
def bar_with_custom_axis_label():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(x_data)
    bar.add_yaxis('', y_data)

    bar.set_global_opts(xaxis_opts=opts.AxisOpts(
        # 自定义坐标轴标签，在年份后加上`年`
        axislabel_opts=opts.LabelOpts(formatter='{value}年')))
    return bar


chart = bar_with_custom_axis_label()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a63d347428df4599a6e08918ccfc1e17" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a63d347428df4599a6e08918ccfc1e17 = echarts.init(
#                     document.getElementById('a63d347428df4599a6e08918ccfc1e17'), 'light', {renderer: 'canvas'});
#                 var option_a63d347428df4599a6e08918ccfc1e17 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 44,
#                 174,
#                 186,
#                 63,
#                 51,
#                 21,
#                 26,
#                 50,
#                 111,
#                 127
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}\u5e74"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2014,
#                 2015,
#                 2016,
#                 2017,
#                 2018,
#                 2019
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a63d347428df4599a6e08918ccfc1e17.setOption(option_a63d347428df4599a6e08918ccfc1e17);
#         });
#     </script>

# %%
x_data = [random.randint(0, 20) for _ in range(100)]
y_data = [random.randint(0, 50) for _ in range(100)]


def scatter_with_value_xaxis():
    scatter = Scatter(init_opts=opts.InitOpts(theme='light',
                                              width='1000px',
                                              height='600px'))
    scatter.add_xaxis(x_data)
    scatter.add_yaxis('', y_data)
    # X轴默认数据类型为离散数据，设置为数值型
    scatter.set_global_opts(xaxis_opts=opts.AxisOpts(type_="value"))
    return scatter

chart = scatter_with_value_xaxis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="df46337057fb4ce88a348ae48762ff05" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_df46337057fb4ce88a348ae48762ff05 = echarts.init(
#                     document.getElementById('df46337057fb4ce88a348ae48762ff05'), 'light', {renderer: 'canvas'});
#                 var option_df46337057fb4ce88a348ae48762ff05 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     10,
#                     28
#                 ],
#                 [
#                     7,
#                     18
#                 ],
#                 [
#                     6,
#                     0
#                 ],
#                 [
#                     9,
#                     32
#                 ],
#                 [
#                     3,
#                     35
#                 ],
#                 [
#                     15,
#                     1
#                 ],
#                 [
#                     4,
#                     17
#                 ],
#                 [
#                     8,
#                     17
#                 ],
#                 [
#                     13,
#                     18
#                 ],
#                 [
#                     7,
#                     33
#                 ],
#                 [
#                     16,
#                     37
#                 ],
#                 [
#                     1,
#                     49
#                 ],
#                 [
#                     2,
#                     14
#                 ],
#                 [
#                     20,
#                     14
#                 ],
#                 [
#                     14,
#                     20
#                 ],
#                 [
#                     0,
#                     27
#                 ],
#                 [
#                     20,
#                     0
#                 ],
#                 [
#                     1,
#                     10
#                 ],
#                 [
#                     19,
#                     16
#                 ],
#                 [
#                     19,
#                     49
#                 ],
#                 [
#                     4,
#                     7
#                 ],
#                 [
#                     3,
#                     43
#                 ],
#                 [
#                     1,
#                     15
#                 ],
#                 [
#                     15,
#                     40
#                 ],
#                 [
#                     0,
#                     32
#                 ],
#                 [
#                     20,
#                     2
#                 ],
#                 [
#                     12,
#                     27
#                 ],
#                 [
#                     18,
#                     43
#                 ],
#                 [
#                     3,
#                     22
#                 ],
#                 [
#                     7,
#                     7
#                 ],
#                 [
#                     11,
#                     38
#                 ],
#                 [
#                     19,
#                     48
#                 ],
#                 [
#                     17,
#                     42
#                 ],
#                 [
#                     0,
#                     40
#                 ],
#                 [
#                     1,
#                     13
#                 ],
#                 [
#                     19,
#                     1
#                 ],
#                 [
#                     17,
#                     37
#                 ],
#                 [
#                     19,
#                     15
#                 ],
#                 [
#                     12,
#                     33
#                 ],
#                 [
#                     20,
#                     24
#                 ],
#                 [
#                     15,
#                     29
#                 ],
#                 [
#                     5,
#                     35
#                 ],
#                 [
#                     15,
#                     37
#                 ],
#                 [
#                     17,
#                     16
#                 ],
#                 [
#                     20,
#                     20
#                 ],
#                 [
#                     11,
#                     13
#                 ],
#                 [
#                     2,
#                     1
#                 ],
#                 [
#                     15,
#                     2
#                 ],
#                 [
#                     8,
#                     21
#                 ],
#                 [
#                     12,
#                     37
#                 ],
#                 [
#                     18,
#                     6
#                 ],
#                 [
#                     13,
#                     11
#                 ],
#                 [
#                     20,
#                     44
#                 ],
#                 [
#                     19,
#                     2
#                 ],
#                 [
#                     12,
#                     32
#                 ],
#                 [
#                     7,
#                     1
#                 ],
#                 [
#                     3,
#                     17
#                 ],
#                 [
#                     8,
#                     41
#                 ],
#                 [
#                     20,
#                     46
#                 ],
#                 [
#                     12,
#                     46
#                 ],
#                 [
#                     5,
#                     50
#                 ],
#                 [
#                     13,
#                     10
#                 ],
#                 [
#                     12,
#                     4
#                 ],
#                 [
#                     2,
#                     24
#                 ],
#                 [
#                     1,
#                     44
#                 ],
#                 [
#                     11,
#                     38
#                 ],
#                 [
#                     9,
#                     1
#                 ],
#                 [
#                     7,
#                     46
#                 ],
#                 [
#                     15,
#                     4
#                 ],
#                 [
#                     1,
#                     29
#                 ],
#                 [
#                     0,
#                     27
#                 ],
#                 [
#                     6,
#                     21
#                 ],
#                 [
#                     0,
#                     44
#                 ],
#                 [
#                     3,
#                     31
#                 ],
#                 [
#                     14,
#                     9
#                 ],
#                 [
#                     3,
#                     19
#                 ],
#                 [
#                     12,
#                     13
#                 ],
#                 [
#                     12,
#                     1
#                 ],
#                 [
#                     7,
#                     29
#                 ],
#                 [
#                     14,
#                     44
#                 ],
#                 [
#                     16,
#                     37
#                 ],
#                 [
#                     16,
#                     43
#                 ],
#                 [
#                     12,
#                     40
#                 ],
#                 [
#                     19,
#                     33
#                 ],
#                 [
#                     11,
#                     47

# %%
x_data = ['香蕉', '梨子', '水蜜桃', '核桃', '西瓜', '苹果']
y_data_1 = [random.randint(10, 50) for _ in range(len(x_data))]
y_data_2 = [random.randint(100, 500) for _ in range(len(x_data))]


def bar_line_combine_with_two_axis():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(x_data)
    # 添加一个Y轴
    bar.extend_axis(yaxis=opts.AxisOpts())
    bar.add_yaxis('左边Y轴', y_data_1, yaxis_index=0)

    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(x_data)
    # 将line数据通过yaxis_index指向后添加的Y轴
    line.add_yaxis('右边Y轴', y_data_2, yaxis_index=1)

    bar.overlap(line)
    return bar


chart = bar_line_combine_with_two_axis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8cd8d21dec8e4c9b983df8df003d59c9" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8cd8d21dec8e4c9b983df8df003d59c9 = echarts.init(
#                     document.getElementById('8cd8d21dec8e4c9b983df8df003d59c9'), 'light', {renderer: 'canvas'});
#                 var option_8cd8d21dec8e4c9b983df8df003d59c9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5de6\u8fb9Y\u8f74",
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 49,
#                 43,
#                 12,
#                 40,
#                 37,
#                 29
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u53f3\u8fb9Y\u8f74",
#             "connectNulls": false,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u9999\u8549",
#                     380
#                 ],
#                 [
#                     "\u68a8\u5b50",
#                     495
#                 ],
#                 [
#                     "\u6c34\u871c\u6843",
#                     496
#                 ],
#                 [
#                     "\u6838\u6843",
#                     338
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     472
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     427
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de6\u8fb9Y\u8f74",
#                 "\u53f3\u8fb9Y\u8f74"
#             ],
#             "selected": {
#                 "\u5de6\u8fb9Y\u8f74": true,
#                 "\u53f3\u8fb9Y\u8f74": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u9999\u8549",
#                 "\u68a8\u5b50",
#                 "\u6c34\u871c\u6843",
#                 "\u6838\u6843",
#                 "\u897f\u74dc",
#                 "\u82f9\u679c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_8cd8d21dec8e4c9b983df8df003d59c9.setOption(option_8cd8d21dec8e4c9b983df8df003d59c9);
#         });
#     </script>

# %%
x_data = ['香蕉', '梨子', '水蜜桃', '核桃', '西瓜', '苹果']
y_data_1 = [random.randint(10, 50) for _ in range(len(x_data))]
y_data_2 = [random.randint(100, 500) for _ in range(len(x_data))]


def bar_with_multiple_axis():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(x_data)
    # 添加一个Y轴
    bar.extend_axis(yaxis=opts.AxisOpts())
    # 分别指定使用的Y轴
    bar.add_yaxis('左边Y轴', y_data_1, yaxis_index=0)
    bar.add_yaxis('右边Y轴', y_data_2, yaxis_index=1)
    return bar


chart = bar_with_multiple_axis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="14822e424e384113bea6a4f8689e8d1a" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_14822e424e384113bea6a4f8689e8d1a = echarts.init(
#                     document.getElementById('14822e424e384113bea6a4f8689e8d1a'), 'light', {renderer: 'canvas'});
#                 var option_14822e424e384113bea6a4f8689e8d1a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5de6\u8fb9Y\u8f74",
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 40,
#                 16,
#                 28,
#                 15,
#                 23,
#                 41
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u53f3\u8fb9Y\u8f74",
#             "yAxisIndex": 1,
#             "legendHoverLink": true,
#             "data": [
#                 453,
#                 305,
#                 432,
#                 309,
#                 158,
#                 154
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de6\u8fb9Y\u8f74",
#                 "\u53f3\u8fb9Y\u8f74"
#             ],
#             "selected": {
#                 "\u5de6\u8fb9Y\u8f74": true,
#                 "\u53f3\u8fb9Y\u8f74": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u9999\u8549",
#                 "\u68a8\u5b50",
#                 "\u6c34\u871c\u6843",
#                 "\u6838\u6843",
#                 "\u897f\u74dc",
#                 "\u82f9\u679c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_14822e424e384113bea6a4f8689e8d1a.setOption(option_14822e424e384113bea6a4f8689e8d1a);
#         });
#     </script>

# %%
x_data_1 = ["2020/10/{}".format(i + 1) for i in range(30)]
x_data_2 = ["2019/10/{}".format(i + 1) for i in range(30)]
y_data_1 = [random.randint(10, 50) for _ in range(30)]
y_data_2 = [random.randint(20, 60) for _ in range(30)]


def line_with_two_xaxis():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(x_data_1)
    # 添加一个x轴
    line.extend_axis(xaxis_data=x_data_2, xaxis=opts.AxisOpts())
    line.add_yaxis('下面X轴', y_data_1)
    line.add_yaxis('上面X轴', y_data_2)
    return line


chart = line_with_two_xaxis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1805e06a60644db69e83085175be3419" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1805e06a60644db69e83085175be3419 = echarts.init(
#                     document.getElementById('1805e06a60644db69e83085175be3419'), 'light', {renderer: 'canvas'});
#                 var option_1805e06a60644db69e83085175be3419 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4e0b\u9762X\u8f74",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020/10/1",
#                     44
#                 ],
#                 [
#                     "2020/10/2",
#                     45
#                 ],
#                 [
#                     "2020/10/3",
#                     39
#                 ],
#                 [
#                     "2020/10/4",
#                     24
#                 ],
#                 [
#                     "2020/10/5",
#                     28
#                 ],
#                 [
#                     "2020/10/6",
#                     16
#                 ],
#                 [
#                     "2020/10/7",
#                     39
#                 ],
#                 [
#                     "2020/10/8",
#                     48
#                 ],
#                 [
#                     "2020/10/9",
#                     19
#                 ],
#                 [
#                     "2020/10/10",
#                     26
#                 ],
#                 [
#                     "2020/10/11",
#                     36
#                 ],
#                 [
#                     "2020/10/12",
#                     34
#                 ],
#                 [
#                     "2020/10/13",
#                     25
#                 ],
#                 [
#                     "2020/10/14",
#                     27
#                 ],
#                 [
#                     "2020/10/15",
#                     30
#                 ],
#                 [
#                     "2020/10/16",
#                     50
#                 ],
#                 [
#                     "2020/10/17",
#                     16
#                 ],
#                 [
#                     "2020/10/18",
#                     36
#                 ],
#                 [
#                     "2020/10/19",
#                     12
#                 ],
#                 [
#                     "2020/10/20",
#                     38
#                 ],
#                 [
#                     "2020/10/21",
#                     28
#                 ],
#                 [
#                     "2020/10/22",
#                     27
#                 ],
#                 [
#                     "2020/10/23",
#                     40
#                 ],
#                 [
#                     "2020/10/24",
#                     39
#                 ],
#                 [
#                     "2020/10/25",
#                     20
#                 ],
#                 [
#                     "2020/10/26",
#                     38
#                 ],
#                 [
#                     "2020/10/27",
#                     17
#                 ],
#                 [
#                     "2020/10/28",
#                     47
#                 ],
#                 [
#                     "2020/10/29",
#                     26
#                 ],
#                 [
#                     "2020/10/30",
#                     19
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u4e0a\u9762X\u8f74",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020/10/1",
#                     58
#                 ],
#                 [
#                     "2020/10/2",
#                     46
#                 ],
#                 [
#                     "2020/10/3",
#                     23
#                 ],
#                 [
#                     "2020/10/4",
#                     28
#                 ],
#                 [
#                     "2020/10/5",
#                     32
#                 ],
#                 [
#                     "2020/10/6",
#                     50
#                 ],
#                 [
#                     "2020/10/7",
#                     59
#                 ],
#                 [
#                     "2020/10/8",
#                     25
#                 ],
#                 [
#                     "2020/10/9",
#                     31
#                 ],
#                 [
#                     "2020/10/10",
#                     23
#                 ],
#                 [
#                     "2020/10/11",
#                     34
#                 ],
#                 [
#                     "2020/10/12",
#                     34
#                 ],
#                 [
#                     "2020/10/13",
#                     28
#                 ],
#                 [
#                     "2020/10/14",
#                     20
#                 ],
#                 [
#                     "2020/10/15",
#                     59
#                 ],
#                 [
#                     "2020/10/16",
#                     26
#                 ],
#                 [
#                     "2020/10/17",
#                     45
#                 ],
#                 [
#                     "2020/10/18",
#                     42
#                 ],
#                 [
#                     "2020/10/19",
#                     60
#                 ],
#                 [
#                     "2020/10/20",
#                     30
#                 ],
#                 [
#                     "2020/10/21",
#                     39
#                 ],
#                 [
#                     "2020/10/22",
#                     50
#                 ],
#                 [
#                     "2020/10/23",
#                     41
#                 ],
#                 [
#                     "2020/10/24",
#                     43
#                 ],
#                 [
#                     "2020/10/25",
#                     49
#                 ],
#                 [
#                     "2020/10/26",
#                     25
#                 ],
#                 [
#                     "2020/10/27",
#                     37
#                 ],
#                 [
#                     "2020/10/28",
#                     24
#                 ],
#                 [
#                     "2020/10/29",
#                     51
#                 ],
#                 [
#                     "2020/10/30",
#                     21
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
